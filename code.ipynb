# %% [markdown]
# ChloroGuard - Leaf Disease Detection
# Detect and classify plant leaf diseases using CNN and OpenCV.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import os

# %% [markdown]
# for evaluation

# %%
import matplotlib.pyplot as plt

# %%
img_size = 224
batch = 32
data_dir = 'data/PlantVillage'

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True,
    shear_range=0.2,
    validation_split=0.2
)

train_data = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_size, img_size),
    batch_size=batch,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

valid_data = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_size, img_size),
    batch_size=batch,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 16516 images belonging to 15 classes.
# Found 4122 images belonging to 15 classes.
# Found 4122 images belonging to 15 classes.

# %%
import tensorflow as tf
model_path = 'models/plant_disease_mobilenetv2_deploy.keras'
model = tf.keras.models.load_model(model_path)

# %%
loss, acc = model.evaluate(valid_data, verbose=1)
print('Validation accuracy:', acc)
print('Validation loss:', loss)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 loss, acc = model.evaluate(valid_data, verbose=1)
#       2 print('Validation accuracy:', acc)
#       3 print('Validation loss:', loss)
#
# File c:\Users\SHARFAN\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\SHARFAN\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\trainers\trainer.py:1058, in Trainer._assert_compile_called(self, method_name)
#    1056 else:
#    1057     msg += f"calling `{method_name}()`."
# -> 1058 raise ValueError(msg)
#
# ValueError: You must call `compile()` before using the model.
